# %%
import numpy as np
import matplotlib.pyplot as plt
 
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms

torch.use_deterministic_algorithms(True)

# %%
class LeNet(nn.Module):

    def __init__(self):
        super(LeNet, self).__init__()
        # 3 input image channel, 6 output feature maps and 5x5 conv kernel
        self.cn1 = nn.Conv2d(3, 6, 5)
        # 6 input image channel, 16 output feature maps and 5x5 conv kernel
        self.cn2 = nn.Conv2d(6, 16, 5)
        # fully connected layers of size 120, 84 and 10
        self.fc1 = nn.Linear(16 * 5 * 5, 120)  # 5*5 is the spatial dimension at this layer
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        # Convolution with 5x5 kernel
        x = F.relu(self.cn1(x))
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(x, (2, 2))
        # Convolution with 5x5 kernel
        x = F.relu(self.cn2(x))
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(x, (2, 2))
        # Flatten spatial and depth dimensions into a single vector
        x = x.view(-1, self.flattened_features(x))
        # Fully connected operations
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

    def flattened_features(self, x):
        # all except the first (batch) dimension
        size = x.size()[1:]  
        num_feats = 1
        for s in size:
            num_feats *= s
        return num_feats


lenet = LeNet()
print(lenet)
# Out:
# LeNet(
#   (cn1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (cn2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
def train(net, trainloader, optim, epoch):
    # initialize loss
    loss_total = 0.0
    
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        # ip refers to the input images, and ground_truth refers to the output classes the images belong to
        ip, ground_truth = data

        # zero the parameter gradients
        optim.zero_grad()

        # forward pass + backward pass + optimization step
        op = net(ip)
        loss = nn.CrossEntropyLoss()(op, ground_truth)
        loss.backward()
        optim.step()

        # update loss
        loss_total += loss.item()
        
        # print loss statistics
        if (i+1) % 1000 == 0:    # print at the interval of 1000 mini-batches
            print('[Epoch number : %d, Mini-batches: %5d] loss: %.3f' %
                  (epoch + 1, i + 1, loss_total / 200))
            loss_total = 0.0

# %%
def test(net, testloader):
    success = 0
    counter = 0
    with torch.no_grad():
        for data in testloader:
            im, ground_truth = data
            op = net(im)
            _, pred = torch.max(op.data, 1)
            counter += ground_truth.size(0)
            success += (pred == ground_truth).sum().item()

    print('LeNet accuracy on 10000 images from test dataset: %d %%' % (
        100 * success / counter))

# %%
# The mean and std are kept as 0.5 for normalizing pixel values as the pixel values are originally in the range 0 to 1
train_transform = transforms.Compose([transforms.RandomHorizontalFlip(),
                                      transforms.RandomCrop(32, 4),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=8, shuffle=True)


test_transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=10000, shuffle=False)


# ordering is important
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100.0%
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
# define a function that displays an image
def imageshow(image):
    # un-normalize the image
    image = image/2 + 0.5     
    npimage = image.numpy()
    plt.imshow(np.transpose(npimage, (1, 2, 0)))
    plt.show()


# sample images from training set
dataiter = iter(trainloader)
images, labels = next(dataiter)

# display images in a grid
num_images = 4
imageshow(torchvision.utils.make_grid(images[:num_images]))
# print labels
print('    '+'  ||  '.join(classes[labels[j]] for j in range(num_images)))
# Out:
#     deer  ||  dog  ||  cat  ||  plane

# %%
# define optimizer
optim = torch.optim.Adam(lenet.parameters(), lr=0.001)

# training loop over the dataset multiple times
for epoch in range(50):  
    train(lenet, trainloader, optim, epoch)
    print()
    test(lenet, testloader)
    print()

print('Finished Training')
# Out:
# [Epoch number : 1, Mini-batches:  1000] loss: 10.101
# [Epoch number : 1, Mini-batches:  2000] loss: 8.933
# [Epoch number : 1, Mini-batches:  3000] loss: 8.443
# [Epoch number : 1, Mini-batches:  4000] loss: 8.207
# [Epoch number : 1, Mini-batches:  5000] loss: 7.986
# [Epoch number : 1, Mini-batches:  6000] loss: 7.765
#
# LeNet accuracy on 10000 images from test dataset: 47 %
#
# [Epoch number : 2, Mini-batches:  1000] loss: 7.472
# [Epoch number : 2, Mini-batches:  2000] loss: 7.383
# [Epoch number : 2, Mini-batches:  3000] loss: 7.277
# [Epoch number : 2, Mini-batches:  4000] loss: 7.213
# [Epoch number : 2, Mini-batches:  5000] loss: 7.155
# [Epoch number : 2, Mini-batches:  6000] loss: 6.925
#
# LeNet accuracy on 10000 images from test dataset: 50 %
#
# [Epoch number : 3, Mini-batches:  1000] loss: 6.910
# [Epoch number : 3, Mini-batches:  2000] loss: 6.904
# [Epoch number : 3, Mini-batches:  3000] loss: 6.789
# [Epoch number : 3, Mini-batches:  4000] loss: 6.732
# [Epoch number : 3, Mini-batches:  5000] loss: 6.720
# [Epoch number : 3, Mini-batches:  6000] loss: 6.684
#
# LeNet accuracy on 10000 images from test dataset: 55 %
#
# [Epoch number : 4, Mini-batches:  1000] loss: 6.658
# [Epoch number : 4, Mini-batches:  2000] loss: 6.518
# [Epoch number : 4, Mini-batches:  3000] loss: 6.451
# [Epoch number : 4, Mini-batches:  4000] loss: 6.442
# [Epoch number : 4, Mini-batches:  5000] loss: 6.406
# [Epoch number : 4, Mini-batches:  6000] loss: 6.491
#
# LeNet accuracy on 10000 images from test dataset: 58 %
#
# [Epoch number : 5, Mini-batches:  1000] loss: 6.238
# [Epoch number : 5, Mini-batches:  2000] loss: 6.234
# [Epoch number : 5, Mini-batches:  3000] loss: 6.502
# [Epoch number : 5, Mini-batches:  4000] loss: 6.406
# [Epoch number : 5, Mini-batches:  5000] loss: 6.305
# [Epoch number : 5, Mini-batches:  6000] loss: 6.118
#
# LeNet accuracy on 10000 images from test dataset: 59 %
#
# [Epoch number : 6, Mini-batches:  1000] loss: 6.102
# [Epoch number : 6, Mini-batches:  2000] loss: 6.145
# [Epoch number : 6, Mini-batches:  3000] loss: 6.161
# [Epoch number : 6, Mini-batches:  4000] loss: 6.235
# [Epoch number : 6, Mini-batches:  5000] loss: 6.173
# [Epoch number : 6, Mini-batches:  6000] loss: 6.164
#
# LeNet accuracy on 10000 images from test dataset: 59 %
#
# [Epoch number : 7, Mini-batches:  1000] loss: 5.986
# [Epoch number : 7, Mini-batches:  2000] loss: 6.049
# [Epoch number : 7, Mini-batches:  3000] loss: 6.134
# [Epoch number : 7, Mini-batches:  4000] loss: 5.971
# [Epoch number : 7, Mini-batches:  5000] loss: 5.980
# [Epoch number : 7, Mini-batches:  6000] loss: 6.026
#
# LeNet accuracy on 10000 images from test dataset: 60 %
#
# [Epoch number : 8, Mini-batches:  1000] loss: 5.960
# [Epoch number : 8, Mini-batches:  2000] loss: 5.929
# [Epoch number : 8, Mini-batches:  3000] loss: 5.961
# [Epoch number : 8, Mini-batches:  4000] loss: 5.881
# [Epoch number : 8, Mini-batches:  5000] loss: 5.836
# [Epoch number : 8, Mini-batches:  6000] loss: 6.046
#
# LeNet accuracy on 10000 images from test dataset: 59 %
#
# [Epoch number : 9, Mini-batches:  1000] loss: 5.906
# [Epoch number : 9, Mini-batches:  2000] loss: 5.810
# [Epoch number : 9, Mini-batches:  3000] loss: 5.929
# [Epoch number : 9, Mini-batches:  4000] loss: 5.860
# [Epoch number : 9, Mini-batches:  5000] loss: 5.804
# [Epoch number : 9, Mini-batches:  6000] loss: 5.933
#
# LeNet accuracy on 10000 images from test dataset: 61 %
#
# [Epoch number : 10, Mini-batches:  1000] loss: 5.766
# [Epoch number : 10, Mini-batches:  2000] loss: 5.815
# [Epoch number : 10, Mini-batches:  3000] loss: 5.884
# [Epoch number : 10, Mini-batches:  4000] loss: 5.827
# [Epoch number : 10, Mini-batches:  5000] loss: 5.719
# [Epoch number : 10, Mini-batches:  6000] loss: 5.760
#
# LeNet accuracy on 10000 images from test dataset: 61 %
#
# [Epoch number : 11, Mini-batches:  1000] loss: 5.646
# [Epoch number : 11, Mini-batches:  2000] loss: 5.683
# [Epoch number : 11, Mini-batches:  3000] loss: 5.736
# [Epoch number : 11, Mini-batches:  4000] loss: 5.771
# [Epoch number : 11, Mini-batches:  5000] loss: 5.734
# [Epoch number : 11, Mini-batches:  6000] loss: 5.731
#
# LeNet accuracy on 10000 images from test dataset: 62 %
#
# [Epoch number : 12, Mini-batches:  1000] loss: 5.723
# [Epoch number : 12, Mini-batches:  2000] loss: 5.659
# [Epoch number : 12, Mini-batches:  3000] loss: 5.656
# [Epoch number : 12, Mini-batches:  4000] loss: 5.738
# [Epoch number : 12, Mini-batches:  5000] loss: 5.643
# [Epoch number : 12, Mini-batches:  6000] loss: 5.670
#
# LeNet accuracy on 10000 images from test dataset: 62 %
#
# [Epoch number : 13, Mini-batches:  1000] loss: 5.648
# [Epoch number : 13, Mini-batches:  2000] loss: 5.570
# [Epoch number : 13, Mini-batches:  3000] loss: 5.586
# [Epoch number : 13, Mini-batches:  4000] loss: 5.575
# [Epoch number : 13, Mini-batches:  5000] loss: 5.615
# [Epoch number : 13, Mini-batches:  6000] loss: 5.674
#
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 14, Mini-batches:  1000] loss: 5.414
# [Epoch number : 14, Mini-batches:  2000] loss: 5.555
# [Epoch number : 14, Mini-batches:  3000] loss: 5.702
# [Epoch number : 14, Mini-batches:  4000] loss: 5.616
# [Epoch number : 14, Mini-batches:  5000] loss: 5.579
# [Epoch number : 14, Mini-batches:  6000] loss: 5.576
#
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 15, Mini-batches:  1000] loss: 5.505
# [Epoch number : 15, Mini-batches:  2000] loss: 5.525
# [Epoch number : 15, Mini-batches:  3000] loss: 5.583
# [Epoch number : 15, Mini-batches:  4000] loss: 5.541
# [Epoch number : 15, Mini-batches:  5000] loss: 5.480
# [Epoch number : 15, Mini-batches:  6000] loss: 5.551
#
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 16, Mini-batches:  1000] loss: 5.432
# [Epoch number : 16, Mini-batches:  2000] loss: 5.500
# [Epoch number : 16, Mini-batches:  3000] loss: 5.581
# [Epoch number : 16, Mini-batches:  4000] loss: 5.486
# [Epoch number : 16, Mini-batches:  5000] loss: 5.396
# [Epoch number : 16, Mini-batches:  6000] loss: 5.541
#
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 17, Mini-batches:  1000] loss: 5.468
# [Epoch number : 17, Mini-batches:  2000] loss: 5.498
# [Epoch number : 17, Mini-batches:  3000] loss: 5.370
# [Epoch number : 17, Mini-batches:  4000] loss: 5.469
# [Epoch number : 17, Mini-batches:  5000] loss: 5.458
# [Epoch number : 17, Mini-batches:  6000] loss: 5.542
#
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 18, Mini-batches:  1000] loss: 5.286
# [Epoch number : 18, Mini-batches:  2000] loss: 5.469
# [Epoch number : 18, Mini-batches:  3000] loss: 5.420
# [Epoch number : 18, Mini-batches:  4000] loss: 5.503
# [Epoch number : 18, Mini-batches:  5000] loss: 5.314
# [Epoch number : 18, Mini-batches:  6000] loss: 5.536
#
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 19, Mini-batches:  1000] loss: 5.419
# [Epoch number : 19, Mini-batches:  2000] loss: 5.526
# [Epoch number : 19, Mini-batches:  3000] loss: 5.410
# [Epoch number : 19, Mini-batches:  4000] loss: 5.292
# [Epoch number : 19, Mini-batches:  5000] loss: 5.399
# [Epoch number : 19, Mini-batches:  6000] loss: 5.509
#
# LeNet accuracy on 10000 images from test dataset: 64 %
#
# [Epoch number : 20, Mini-batches:  1000] loss: 5.434
# [Epoch number : 20, Mini-batches:  2000] loss: 5.384
# [Epoch number : 20, Mini-batches:  3000] loss: 5.375
# [Epoch number : 20, Mini-batches:  4000] loss: 5.270
# [Epoch number : 20, Mini-batches:  5000] loss: 5.411
# [Epoch number : 20, Mini-batches:  6000] loss: 5.339
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 21, Mini-batches:  1000] loss: 5.399
# [Epoch number : 21, Mini-batches:  2000] loss: 5.336
# [Epoch number : 21, Mini-batches:  3000] loss: 5.398
# [Epoch number : 21, Mini-batches:  4000] loss: 5.452
# [Epoch number : 21, Mini-batches:  5000] loss: 5.374
# [Epoch number : 21, Mini-batches:  6000] loss: 5.377
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 22, Mini-batches:  1000] loss: 5.240
# [Epoch number : 22, Mini-batches:  2000] loss: 5.404
# [Epoch number : 22, Mini-batches:  3000] loss: 5.373
# [Epoch number : 22, Mini-batches:  4000] loss: 5.358
# [Epoch number : 22, Mini-batches:  5000] loss: 5.464
# [Epoch number : 22, Mini-batches:  6000] loss: 5.291
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 23, Mini-batches:  1000] loss: 5.340
# [Epoch number : 23, Mini-batches:  2000] loss: 5.303
# [Epoch number : 23, Mini-batches:  3000] loss: 5.298
# [Epoch number : 23, Mini-batches:  4000] loss: 5.269
# [Epoch number : 23, Mini-batches:  5000] loss: 5.267
# [Epoch number : 23, Mini-batches:  6000] loss: 5.354
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 24, Mini-batches:  1000] loss: 5.293
# [Epoch number : 24, Mini-batches:  2000] loss: 5.216
# [Epoch number : 24, Mini-batches:  3000] loss: 5.259
# [Epoch number : 24, Mini-batches:  4000] loss: 5.265
# [Epoch number : 24, Mini-batches:  5000] loss: 5.437
# [Epoch number : 24, Mini-batches:  6000] loss: 5.375
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 25, Mini-batches:  1000] loss: 5.291
# [Epoch number : 25, Mini-batches:  2000] loss: 5.194
# [Epoch number : 25, Mini-batches:  3000] loss: 5.256
# [Epoch number : 25, Mini-batches:  4000] loss: 5.272
# [Epoch number : 25, Mini-batches:  5000] loss: 5.346
# [Epoch number : 25, Mini-batches:  6000] loss: 5.347
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 26, Mini-batches:  1000] loss: 5.282
# [Epoch number : 26, Mini-batches:  2000] loss: 5.278
# [Epoch number : 26, Mini-batches:  3000] loss: 5.354
# [Epoch number : 26, Mini-batches:  4000] loss: 5.271
# [Epoch number : 26, Mini-batches:  5000] loss: 5.292
# [Epoch number : 26, Mini-batches:  6000] loss: 5.227
#
# LeNet accuracy on 10000 images from test dataset: 63 %
#
# [Epoch number : 27, Mini-batches:  1000] loss: 5.244
# [Epoch number : 27, Mini-batches:  2000] loss: 5.109
# [Epoch number : 27, Mini-batches:  3000] loss: 5.487
# [Epoch number : 27, Mini-batches:  4000] loss: 5.300
# [Epoch number : 27, Mini-batches:  5000] loss: 5.235
# [Epoch number : 27, Mini-batches:  6000] loss: 5.239
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 28, Mini-batches:  1000] loss: 5.263
# [Epoch number : 28, Mini-batches:  2000] loss: 5.140
# [Epoch number : 28, Mini-batches:  3000] loss: 5.258
# [Epoch number : 28, Mini-batches:  4000] loss: 5.234
# [Epoch number : 28, Mini-batches:  5000] loss: 5.203
# [Epoch number : 28, Mini-batches:  6000] loss: 5.395
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 29, Mini-batches:  1000] loss: 5.179
# [Epoch number : 29, Mini-batches:  2000] loss: 5.295
# [Epoch number : 29, Mini-batches:  3000] loss: 5.190
# [Epoch number : 29, Mini-batches:  4000] loss: 5.201
# [Epoch number : 29, Mini-batches:  5000] loss: 5.228
# [Epoch number : 29, Mini-batches:  6000] loss: 5.147
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 30, Mini-batches:  1000] loss: 5.133
# [Epoch number : 30, Mini-batches:  2000] loss: 5.367
# [Epoch number : 30, Mini-batches:  3000] loss: 5.253
# [Epoch number : 30, Mini-batches:  4000] loss: 5.179
# [Epoch number : 30, Mini-batches:  5000] loss: 5.196
# [Epoch number : 30, Mini-batches:  6000] loss: 5.164
#
# LeNet accuracy on 10000 images from test dataset: 65 %
#
# [Epoch number : 31, Mini-batches:  1000] loss: 5.183
# [Epoch number : 31, Mini-batches:  2000] loss: 5.270
# [Epoch number : 31, Mini-batches:  3000] loss: 5.200
# [Epoch number : 31, Mini-batches:  4000] loss: 5.083
# [Epoch number : 31, Mini-batches:  5000] loss: 5.230
# [Epoch number : 31, Mini-batches:  6000] loss: 5.224
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 32, Mini-batches:  1000] loss: 5.019
# [Epoch number : 32, Mini-batches:  2000] loss: 5.141
# [Epoch number : 32, Mini-batches:  3000] loss: 5.113
# [Epoch number : 32, Mini-batches:  4000] loss: 5.280
# [Epoch number : 32, Mini-batches:  5000] loss: 5.293
# [Epoch number : 32, Mini-batches:  6000] loss: 5.196
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 33, Mini-batches:  1000] loss: 5.052
# [Epoch number : 33, Mini-batches:  2000] loss: 5.067
# [Epoch number : 33, Mini-batches:  3000] loss: 5.229
# [Epoch number : 33, Mini-batches:  4000] loss: 5.303
# [Epoch number : 33, Mini-batches:  5000] loss: 5.258
# [Epoch number : 33, Mini-batches:  6000] loss: 5.230
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 34, Mini-batches:  1000] loss: 5.169
# [Epoch number : 34, Mini-batches:  2000] loss: 5.078
# [Epoch number : 34, Mini-batches:  3000] loss: 5.210
# [Epoch number : 34, Mini-batches:  4000] loss: 5.120
# [Epoch number : 34, Mini-batches:  5000] loss: 5.126
# [Epoch number : 34, Mini-batches:  6000] loss: 5.139
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 35, Mini-batches:  1000] loss: 5.059
# [Epoch number : 35, Mini-batches:  2000] loss: 5.166
# [Epoch number : 35, Mini-batches:  3000] loss: 5.169
# [Epoch number : 35, Mini-batches:  4000] loss: 5.085
# [Epoch number : 35, Mini-batches:  5000] loss: 5.184
# [Epoch number : 35, Mini-batches:  6000] loss: 5.096
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 36, Mini-batches:  1000] loss: 5.005
# [Epoch number : 36, Mini-batches:  2000] loss: 5.027
# [Epoch number : 36, Mini-batches:  3000] loss: 5.126
# [Epoch number : 36, Mini-batches:  4000] loss: 5.253
# [Epoch number : 36, Mini-batches:  5000] loss: 5.105
# [Epoch number : 36, Mini-batches:  6000] loss: 5.092
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 37, Mini-batches:  1000] loss: 5.091
# [Epoch number : 37, Mini-batches:  2000] loss: 5.094
# [Epoch number : 37, Mini-batches:  3000] loss: 5.057
# [Epoch number : 37, Mini-batches:  4000] loss: 5.034
# [Epoch number : 37, Mini-batches:  5000] loss: 5.241
# [Epoch number : 37, Mini-batches:  6000] loss: 5.098
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 38, Mini-batches:  1000] loss: 5.000
# [Epoch number : 38, Mini-batches:  2000] loss: 4.946
# [Epoch number : 38, Mini-batches:  3000] loss: 5.034
# [Epoch number : 38, Mini-batches:  4000] loss: 5.121
# [Epoch number : 38, Mini-batches:  5000] loss: 5.124
# [Epoch number : 38, Mini-batches:  6000] loss: 5.178
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 39, Mini-batches:  1000] loss: 5.127
# [Epoch number : 39, Mini-batches:  2000] loss: 5.106
# [Epoch number : 39, Mini-batches:  3000] loss: 5.074
# [Epoch number : 39, Mini-batches:  4000] loss: 5.073
# [Epoch number : 39, Mini-batches:  5000] loss: 5.002
# [Epoch number : 39, Mini-batches:  6000] loss: 5.023
#
# LeNet accuracy on 10000 images from test dataset: 68 %
#
# [Epoch number : 40, Mini-batches:  1000] loss: 5.074
# [Epoch number : 40, Mini-batches:  2000] loss: 5.080
# [Epoch number : 40, Mini-batches:  3000] loss: 5.071
# [Epoch number : 40, Mini-batches:  4000] loss: 5.006
# [Epoch number : 40, Mini-batches:  5000] loss: 5.219
# [Epoch number : 40, Mini-batches:  6000] loss: 5.079
#
# LeNet accuracy on 10000 images from test dataset: 66 %
#
# [Epoch number : 41, Mini-batches:  1000] loss: 5.102
# [Epoch number : 41, Mini-batches:  2000] loss: 5.077
# [Epoch number : 41, Mini-batches:  3000] loss: 5.113
# [Epoch number : 41, Mini-batches:  4000] loss: 5.122
# [Epoch number : 41, Mini-batches:  5000] loss: 4.989
# [Epoch number : 41, Mini-batches:  6000] loss: 5.105
#
# LeNet accuracy on 10000 images from test dataset: 68 %
#
# [Epoch number : 42, Mini-batches:  1000] loss: 5.066
# [Epoch number : 42, Mini-batches:  2000] loss: 5.011
# [Epoch number : 42, Mini-batches:  3000] loss: 5.095
# [Epoch number : 42, Mini-batches:  4000] loss: 5.002
# [Epoch number : 42, Mini-batches:  5000] loss: 5.130
# [Epoch number : 42, Mini-batches:  6000] loss: 5.066
#
# LeNet accuracy on 10000 images from test dataset: 68 %
#
# [Epoch number : 43, Mini-batches:  1000] loss: 5.032
# [Epoch number : 43, Mini-batches:  2000] loss: 5.197
# [Epoch number : 43, Mini-batches:  3000] loss: 5.054
# [Epoch number : 43, Mini-batches:  4000] loss: 4.979
# [Epoch number : 43, Mini-batches:  5000] loss: 4.891
# [Epoch number : 43, Mini-batches:  6000] loss: 5.095
#
# LeNet accuracy on 10000 images from test dataset: 68 %
#
# [Epoch number : 44, Mini-batches:  1000] loss: 5.038
# [Epoch number : 44, Mini-batches:  2000] loss: 5.058
# [Epoch number : 44, Mini-batches:  3000] loss: 4.973
# [Epoch number : 44, Mini-batches:  4000] loss: 5.115
# [Epoch number : 44, Mini-batches:  5000] loss: 5.131
# [Epoch number : 44, Mini-batches:  6000] loss: 4.937
#
# LeNet accuracy on 10000 images from test dataset: 69 %
#
# [Epoch number : 45, Mini-batches:  1000] loss: 5.159
# [Epoch number : 45, Mini-batches:  2000] loss: 5.047
# [Epoch number : 45, Mini-batches:  3000] loss: 4.984
# [Epoch number : 45, Mini-batches:  4000] loss: 5.087
# [Epoch number : 45, Mini-batches:  5000] loss: 4.992
# [Epoch number : 45, Mini-batches:  6000] loss: 5.083
#
# LeNet accuracy on 10000 images from test dataset: 68 %
#
# [Epoch number : 46, Mini-batches:  1000] loss: 4.957
# [Epoch number : 46, Mini-batches:  2000] loss: 5.078
# [Epoch number : 46, Mini-batches:  3000] loss: 5.027
# [Epoch number : 46, Mini-batches:  4000] loss: 5.059
# [Epoch number : 46, Mini-batches:  5000] loss: 5.036
# [Epoch number : 46, Mini-batches:  6000] loss: 5.074
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 47, Mini-batches:  1000] loss: 5.129
# [Epoch number : 47, Mini-batches:  2000] loss: 4.992
# [Epoch number : 47, Mini-batches:  3000] loss: 4.976
# [Epoch number : 47, Mini-batches:  4000] loss: 5.137
# [Epoch number : 47, Mini-batches:  5000] loss: 5.009
# [Epoch number : 47, Mini-batches:  6000] loss: 5.035
#
# LeNet accuracy on 10000 images from test dataset: 67 %
#
# [Epoch number : 48, Mini-batches:  1000] loss: 5.078
# [Epoch number : 48, Mini-batches:  2000] loss: 4.977
# [Epoch number : 48, Mini-batches:  3000] loss: 5.046
# [Epoch number : 48, Mini-batches:  4000] loss: 4.918
# [Epoch number : 48, Mini-batches:  5000] loss: 5.040
# [Epoch number : 48, Mini-batches:  6000] loss: 4.965
#
# LeNet accuracy on 10000 images from test dataset: 68 %
#
# [Epoch number : 49, Mini-batches:  1000] loss: 4.984
# [Epoch number : 49, Mini-batches:  2000] loss: 4.901
# [Epoch number : 49, Mini-batches:  3000] loss: 4.988
# [Epoch number : 49, Mini-batches:  4000] loss: 5.029
# [Epoch number : 49, Mini-batches:  5000] loss: 5.068
# [Epoch number : 49, Mini-batches:  6000] loss: 5.043
#
# LeNet accuracy on 10000 images from test dataset: 68 %
#
# [Epoch number : 50, Mini-batches:  1000] loss: 5.111
# [Epoch number : 50, Mini-batches:  2000] loss: 4.909
# [Epoch number : 50, Mini-batches:  3000] loss: 4.935
# [Epoch number : 50, Mini-batches:  4000] loss: 5.041
# [Epoch number : 50, Mini-batches:  5000] loss: 4.937
# [Epoch number : 50, Mini-batches:  6000] loss: 5.080
#
# LeNet accuracy on 10000 images from test dataset: 68 %
#
# Finished Training

# %%
model_path = './cifar_model.pth'
torch.save(lenet.state_dict(), model_path)

# %%
# load test dataset images
d_iter = iter(testloader)
im, ground_truth = next(d_iter)

# print images and ground truth
imageshow(torchvision.utils.make_grid(im[:4]))
print('Label:      ', ' '.join('%5s' % classes[ground_truth[j]] for j in range(4)))

# load model
lenet_cached = LeNet()
lenet_cached.load_state_dict(torch.load(model_path))

# model inference
op = lenet_cached(im)

# print predictions
_, pred = torch.max(op, 1)

print('Prediction: ', ' '.join('%5s' % classes[pred[j]] for j in range(4)))
# Out:
# Label:         cat  ship  ship plane
# /tmp/ipykernel_1324116/18595654.py:11: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   lenet_cached.load_state_dict(torch.load(model_path))
# Prediction:    cat  ship  ship  ship

# %%
success = 0
counter = 0
with torch.no_grad():
    for data in testloader:
        im, ground_truth = data
        op = lenet_cached(im)
        _, pred = torch.max(op.data, 1)
        counter += ground_truth.size(0)
        success += (pred == ground_truth).sum().item()

print('Model accuracy on 10000 images from test dataset: %d %%' % (
    100 * success / counter))
# Out:
# Model accuracy on 10000 images from test dataset: 68 %

# %%
class_sucess = list(0. for i in range(10))
class_counter = list(0. for i in range(10))
with torch.no_grad():
    for data in testloader:
        im, ground_truth = data
        op = lenet_cached(im)
        _, pred = torch.max(op, 1)
        c = (pred == ground_truth).squeeze()
        for i in range(10000):
            ground_truth_curr = ground_truth[i]
            class_sucess[ground_truth_curr] += c[i].item()
            class_counter[ground_truth_curr] += 1


for i in range(10):
    print('Model accuracy for class %5s : %2d %%' % (
        classes[i], 100 * class_sucess[i] / class_counter[i]))
# Out:
# Model accuracy for class plane : 67 %
# Model accuracy for class   car : 87 %
# Model accuracy for class  bird : 53 %
# Model accuracy for class   cat : 39 %
# Model accuracy for class  deer : 62 %
# Model accuracy for class   dog : 72 %
# Model accuracy for class  frog : 70 %
# Model accuracy for class horse : 78 %
# Model accuracy for class  ship : 80 %
# Model accuracy for class truck : 77 %
